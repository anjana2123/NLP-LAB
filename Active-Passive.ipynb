# %%
! pip install Pattern
# Out:
# Collecting Pattern
#   Downloading Pattern-3.6.0.tar.gz (22.2 MB)
#      ---------------------------------------- 0.0/22.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/22.2 MB ? eta -:--:--
#      --------------------------------------- 0.0/22.2 MB 393.8 kB/s eta 0:00:57
#      --------------------------------------- 0.1/22.2 MB 655.4 kB/s eta 0:00:34
#      --------------------------------------- 0.2/22.2 MB 984.6 kB/s eta 0:00:23
#      ---------------------------------------- 0.2/22.2 MB 1.1 MB/s eta 0:00:21
#       --------------------------------------- 0.4/22.2 MB 1.4 MB/s eta 0:00:16
#       --------------------------------------- 0.5/22.2 MB 1.5 MB/s eta 0:00:15
#      - -------------------------------------- 0.6/22.2 MB 1.7 MB/s eta 0:00:13
#      - -------------------------------------- 0.6/22.2 MB 1.7 MB/s eta 0:00:13
#      - -------------------------------------- 0.6/22.2 MB 1.7 MB/s eta 0:00:13
#      - -------------------------------------- 0.6/22.2 MB 1.7 MB/s eta 0:00:13
#      - -------------------------------------- 0.6/22.2 MB 1.7 MB/s eta 0:00:13
#      - -------------------------------------- 0.6/22.2 MB 1.0 MB/s eta 0:00:22
#      - -------------------------------------- 0.7/22.2 MB 1.1 MB/s eta 0:00:21
#      - -------------------------------------- 0.8/22.2 MB 1.2 MB/s eta 0:00:19
#      - -------------------------------------- 1.0/22.2 MB 1.4 MB/s eta 0:00:16
#      -- ------------------------------------- 1.1/22.2 MB 1.5 MB/s eta 0:00:15
#      -- ------------------------------------- 1.4/22.2 MB 1.6 MB/s eta 0:00:13
#      -- ------------------------------------- 1.5/22.2 MB 1.8 MB/s eta 0:00:12
#      -- ------------------------------------- 1.6/22.2 MB 1.8 MB/s eta 0:00:12
#      --- ------------------------------------ 1.8/22.2 MB 1.9 MB/s eta 0:00:11
#      --- ------------------------------------ 2.0/22.2 MB 2.0 MB/s eta 0:00:11
#      --- ------------------------------------ 2.2/22.2 MB 2.1 MB/s eta 0:00:10
#      ---- ----------------------------------- 2.3/22.2 MB 2.1 MB/s eta 0:00:10
#      ---- ----------------------------------- 2.4/22.2 MB 2.1 MB/s eta 0:00:10
#      ---- ----------------------------------- 2.5/22.2 MB 2.1 MB/s eta 0:00:10
#      ---- ----------------------------------- 2.5/22.2 MB 2.1 MB/s eta 0:00:10
#      ---- ----------------------------------- 2.5/22.2 MB 2.1 MB/s eta 0:00:10
#      ---- ----------------------------------- 2.5/22.2 MB 2.1 MB/s eta 0:00:10
#      ---- ----------------------------------- 2.5/22.2 MB 2.1 MB/s eta 0:00:10
#      ---- ----------------------------------- 2.5/22.2 MB 2.1 MB/s eta 0:00:10
#      ---- ----------------------------------- 2.5/22.2 MB 1.7 MB/s eta 0:00:12
#      ---- ----------------------------------- 2.7/22.2 MB 1.8 MB/s eta 0:00:12
#      ----- ---------------------------------- 2.9/22.2 MB 1.8 MB/s eta 0:00:11
#      ----- ---------------------------------- 3.0/22.2 MB 1.9 MB/s eta 0:00:11
#      ----- ---------------------------------- 3.2/22.2 MB 1.9 MB/s eta 0:00:10
#      ------ --------------------------------- 3.5/22.2 MB 2.0 MB/s eta 0:00:10
#      ------ --------------------------------- 3.7/22.2 MB 2.1 MB/s eta 0:00:09
#      ------- -------------------------------- 4.0/22.2 MB 2.2 MB/s eta 0:00:09
#      ------- -------------------------------- 4.2/22.2 MB 2.3 MB/s eta 0:00:08
#      ------- -------------------------------- 4.2/22.2 MB 2.3 MB/s eta 0:00:08
#      ------- -------------------------------- 4.2/22.2 MB 2.3 MB/s eta 0:00:08
#      ------- -------------------------------- 4.2/22.2 MB 2.3 MB/s eta 0:00:08
#      ------- -------------------------------- 4.2/22.2 MB 2.3 MB/s eta 0:00:08
#      ------- -------------------------------- 4.2/22.2 MB 2.3 MB/s eta 0:00:08
#      ------- -------------------------------- 4.2/22.2 MB 2.3 MB/s eta 0:00:08
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.2/22.2 MB 2.0 MB/s eta 0:00:10
#      ------- -------------------------------- 4.3/22.2 MB 1.5 MB/s eta 0:00:13
#      ------- -------------------------------- 4.4/22.2 MB 1.5 MB/s eta 0:00:13
#      ------- -------------------------------- 4.4/22.2 MB 1.5 MB/s eta 0:00:13
#      ------- -------------------------------- 4.4/22.2 MB 1.5 MB/s eta 0:00:13
#      ------- -------------------------------- 4.4/22.2 MB 1.5 MB/s eta 0:00:13
#      ------- -------------------------------- 4.4/22.2 MB 1.5 MB/s eta 0:00:13
#      ------- -------------------------------- 4.4/22.2 MB 1.5 MB/s eta 0:00:13
#      ------- -------------------------------- 4.4/22.2 MB 1.4 MB/s eta 0:00:13
#      ------- -------------------------------- 4.4/22.2 MB 1.4 MB/s eta 0:00:13
#      ------- -------------------------------- 4.4/22.2 MB 1.4 MB/s eta 0:00:13
#      ------- -------------------------------- 4.4/22.2 MB 1.4 MB/s eta 0:00:13
#      ------- -------------------------------- 4.4/22.2 MB 1.4 MB/s eta 0:00:13
#      ------- -------------------------------- 4.4/22.2 MB 1.4 MB/s eta 0:00:13
#      ------- -------------------------------- 4.4/22.2 MB 1.3 MB/s eta 0:00:15
#      -------- ------------------------------- 4.6/22.2 MB 1.3 MB/s eta 0:00:14
#      -------- ------------------------------- 4.7/22.2 MB 1.3 MB/s eta 0:00:14
#      -------- ------------------------------- 4.8/22.2 MB 1.3 MB/s eta 0:00:14
#      -------- ------------------------------- 4.9/22.2 MB 1.3 MB/s eta 0:00:14
#      -------- ------------------------------- 5.0/22.2 MB 1.3 MB/s eta 0:00:14
#      --------- ------------------------------ 5.1/22.2 MB 1.3 MB/s eta 0:00:13
#      --------- ------------------------------ 5.2/22.2 MB 1.4 MB/s eta 0:00:13
#      --------- ------------------------------ 5.4/22.2 MB 1.4 MB/s eta 0:00:13
#      --------- ------------------------------ 5.4/22.2 MB 1.4 MB/s eta 0:00:13
#      ---------- ----------------------------- 5.6/22.2 MB 1.4 MB/s eta 0:00:12
#      ---------- ----------------------------- 5.8/22.2 MB 1.4 MB/s eta 0:00:12
#      ---------- ----------------------------- 6.0/22.2 MB 1.5 MB/s eta 0:00:12
#      ----------- ---------------------------- 6.2/22.2 MB 1.5 MB/s eta 0:00:11
#      ----------- ---------------------------- 6.3/22.2 MB 1.5 MB/s eta 0:00:11
#      ----------- ---------------------------- 6.5/22.2 MB 1.5 MB/s eta 0:00:11
#      ----------- ---------------------------- 6.6/22.2 MB 1.5 MB/s eta 0:00:11
#      ----------- ---------------------------- 6.6/22.2 MB 1.5 MB/s eta 0:00:11
#      ----------- ---------------------------- 6.6/22.2 MB 1.5 MB/s eta 0:00:11
#      ----------- ---------------------------- 6.6/22.2 MB 1.5 MB/s eta 0:00:11
#      ----------- ---------------------------- 6.6/22.2 MB 1.5 MB/s eta 0:00:11
#      ----------- ---------------------------- 6.6/22.2 MB 1.5 MB/s eta 0:00:11
#      ----------- ---------------------------- 6.6/22.2 MB 1.5 MB/s eta 0:00:11
#      ------------ --------------------------- 6.7/22.2 MB 1.5 MB/s eta 0:00:11
#      ------------ --------------------------- 6.8/22.2 MB 1.5 MB/s eta 0:00:11
#      ------------ --------------------------- 6.9/22.2 MB 1.5 MB/s eta 0:00:11
#      ------------ --------------------------- 7.0/22.2 MB 1.5 MB/s eta 0:00:11
#      ------------ --------------------------- 7.1/22.2 MB 1.5 MB/s eta 0:00:11
#      ------------ --------------------------- 7.2/22.2 MB 1.5 MB/s eta 0:00:10
#      ------------- -------------------------- 7.4/22.2 MB 1.5 MB/s eta 0:00:10
#      ------------- -------------------------- 7.6/22.2 MB 1.5 MB/s eta 0:00:10
#      ------------- -------------------------- 7.8/22.2 MB 1.6 MB/s eta 0:00:10
#      -------------- ------------------------- 8.0/22.2 MB 1.6 MB/s eta 0:00:09
#      -------------- ------------------------- 8.1/22.2 MB 1.6 MB/s eta 0:00:09
#      -------------- ------------------------- 8.3/22.2 MB 1.6 MB/s eta 0:00:09
#      --------------- ------------------------ 8.5/22.2 MB 1.6 MB/s eta 0:00:09
#      --------------- ------------------------ 8.6/22.2 MB 1.7 MB/s eta 0:00:09
#      --------------- ------------------------ 8.6/22.2 MB 1.6 MB/s eta 0:00:09
#      --------------- ------------------------ 8.6/22.2 MB 1.6 MB/s eta 0:00:09
MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.9 MB/s eta 0:00:03
#      ------------------------------ --------- 17.0/22.2 MB 1.6 MB/s eta 0:00:04
#      ------------------------------ --------- 17.0/22.2 MB 1.6 MB/s eta 0:00:04
#      ------------------------------ --------- 17.0/22.2 MB 1.6 MB/s eta 0:00:04
#      ------------------------------ --------- 17.0/22.2 MB 1.6 MB/s eta 0:00:04
#      ------------------------------ --------- 17.0/22.2 MB 1.6 MB/s eta 0:00:04
#      ------------------------------ --------- 17.0/22.2 MB 1.6 MB/s eta 0:00:04
#      ------------------------------ --------- 17.1/22.2 MB 1.6 MB/s eta 0:00:04
#      ------------------------------ --------- 17.1/22.2 MB 1.6 MB/s eta 0:00:04
#      ------------------------------ --------- 17.1/22.2 MB 1.6 MB/s eta 0:00:04
#      ------------------------------ --------- 17.1/22.2 MB 1.6 MB/s eta 0:00:04
#      ------------------------------ --------- 17.1/22.2 MB 1.6 MB/s eta 0:00:04
#      ------------------------------ --------- 17.1/22.2 MB 1.6 MB/s eta 0:00:04
#      ------------------------------ --------- 17.1/22.2 MB 1.5 MB/s eta 0:00:04
#      ------------------------------ --------- 17.2/22.2 MB 1.5 MB/s eta 0:00:04
#      ------------------------------- -------- 17.2/22.2 MB 1.5 MB/s eta 0:00:04
#      ------------------------------- -------- 17.2/22.2 MB 1.5 MB/s eta 0:00:04
#      ------------------------------- -------- 17.2/22.2 MB 1.5 MB/s eta 0:00:04
#      ------------------------------- -------- 17.2/22.2 MB 1.5 MB/s eta 0:00:04
#      ------------------------------- -------- 17.2/22.2 MB 1.5 MB/s eta 0:00:04
#      ------------------------------- -------- 17.3/22.2 MB 1.4 MB/s eta 0:00:04
#      ------------------------------- -------- 17.4/22.2 MB 1.5 MB/s eta 0:00:04
#      ------------------------------- -------- 17.5/22.2 MB 1.5 MB/s eta 0:00:04
#      ------------------------------- -------- 17.7/22.2 MB 1.4 MB/s eta 0:00:04
#      -------------------------------- ------- 17.8/22.2 MB 1.4 MB/s eta 0:00:04
#      -------------------------------- ------- 18.0/22.2 MB 1.4 MB/s eta 0:00:03
#      -------------------------------- ------- 18.1/22.2 MB 1.4 MB/s eta 0:00:03
#      -------------------------------- ------- 18.3/22.2 MB 1.4 MB/s eta 0:00:03
#      --------------------------------- ------ 18.5/22.2 MB 1.4 MB/s eta 0:00:03
#      --------------------------------- ------ 18.8/22.2 MB 1.5 MB/s eta 0:00:03
#      ---------------------------------- ----- 19.1/22.2 MB 1.5 MB/s eta 0:00:03
#      ---------------------------------- ----- 19.3/22.2 MB 1.8 MB/s eta 0:00:02
#      ---------------------------------- ----- 19.4/22.2 MB 1.7 MB/s eta 0:00:02
#      ---------------------------------- ----- 19.4/22.2 MB 1.7 MB/s eta 0:00:02
#      ----------------------------------- ---- 19.6/22.2 MB 1.7 MB/s eta 0:00:02
#      ----------------------------------- ---- 19.7/22.2 MB 1.7 MB/s eta 0:00:02
#      ----------------------------------- ---- 19.9/22.2 MB 1.7 MB/s eta 0:00:02
#      ----------------------------------- ---- 20.0/22.2 MB 1.7 MB/s eta 0:00:02
#      ------------------------------------ --- 20.2/22.2 MB 1.7 MB/s eta 0:00:02
#      ------------------------------------ --- 20.4/22.2 MB 1.7 MB/s eta 0:00:02
#      ------------------------------------ --- 20.5/22.2 MB 1.7 MB/s eta 0:00:02
#      ------------------------------------- -- 20.6/22.2 MB 1.7 MB/s eta 0:00:01
#      ------------------------------------- -- 20.6/22.2 MB 1.7 MB/s eta 0:00:01
#      ------------------------------------- -- 20.6/22.2 MB 1.7 MB/s eta 0:00:01
#      ------------------------------------- -- 20.6/22.2 MB 1.7 MB/s eta 0:00:01
#      ------------------------------------- -- 20.6/22.2 MB 1.7 MB/s eta 0:00:01
#      ------------------------------------- -- 20.6/22.2 MB 1.7 MB/s eta 0:00:01
#      ------------------------------------- -- 20.7/22.2 MB 1.6 MB/s eta 0:00:01
#      ------------------------------------- -- 20.7/22.2 MB 1.7 MB/s eta 0:00:01
#      ------------------------------------- -- 20.7/22.2 MB 1.7 MB/s eta 0:00:01
#      ------------------------------------- -- 20.7/22.2 MB 1.7 MB/s eta 0:00:01
#      ------------------------------------- -- 20.7/22.2 MB 1.7 MB/s eta 0:00:01
#      ------------------------------------- -- 20.7/22.2 MB 1.7 MB/s eta 0:00:01
#      ------------------------------------- -- 20.8/22.2 MB 1.6 MB/s eta 0:00:01
#      ------------------------------------- -- 20.8/22.2 MB 1.6 MB/s eta 0:00:01
#      ------------------------------------- -- 20.9/22.2 MB 1.6 MB/s eta 0:00:01
#      ------------------------------------- -- 20.9/22.2 MB 1.6 MB/s eta 0:00:01
#      ------------------------------------- -- 21.1/22.2 MB 1.6 MB/s eta 0:00:01
#      -------------------------------------- - 21.4/22.2 MB 1.6 MB/s eta 0:00:01
#      -------------------------------------- - 21.5/22.2 MB 1.6 MB/s eta 0:00:01
#      -------------------------------------- - 21.6/22.2 MB 1.7 MB/s eta 0:00:01
#      -------------------------------------- - 21.6/22.2 MB 1.7 MB/s eta 0:00:01
#      -------------------------------------- - 21.6/22.2 MB 1.7 MB/s eta 0:00:01
#      -------------------------------------- - 21.6/22.2 MB 1.7 MB/s eta 0:00:01
#      -------------------------------------- - 21.6/22.2 MB 1.7 MB/s eta 0:00:01
#      -------------------------------------- - 21.6/22.2 MB 1.6 MB/s eta 0:00:01
#      -------------------------------------- - 21.6/22.2 MB 1.6 MB/s eta 0:00:01
#      -------------------------------------- - 21.6/22.2 MB 1.6 MB/s eta 0:00:01
#      -------------------------------------- - 21.6/22.2 MB 1.6 MB/s eta 0:00:01
#      -------------------------------------- - 21.6/22.2 MB 1.6 MB/s eta 0:00:01
#      -------------------------------------- - 21.6/22.2 MB 1.6 MB/s eta 0:00:01
#      -------------------------------------- - 21.6/22.2 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  21.7/22.2 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  21.8/22.2 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  22.1/22.2 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------  22.2/22.2 MB 1.3 MB/s eta 0:00:01
#      ---------------------------------------- 22.2/22.2 MB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: future in c:\users\anjan\anaconda3\lib\site-packages (from Pattern) (0.18.3)
# Collecting backports.csv (from Pattern)
#   Downloading backports.csv-1.0.7-py2.py3-none-any.whl.metadata (4.0 kB)
# Collecting mysqlclient (from Pattern)
#   Downloading mysqlclient-2.2.4-cp311-cp311-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\anjan\anaconda3\lib\site-packages (from Pattern) (4.12.2)
# Requirement already satisfied: lxml in c:\users\anjan\anaconda3\lib\site-packages (from Pattern) (4.9.3)
# Collecting feedparser (from Pattern)
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Collecting pdfminer.six (from Pattern)
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy in c:\users\anjan\anaconda3\lib\site-packages (from Pattern) (1.26.4)
# Requirement already satisfied: scipy in c:\users\anjan\anaconda3\lib\site-packages (from Pattern) (1.11.4)
# Requirement already satisfied: nltk in c:\users\anjan\anaconda3\lib\site-packages (from Pattern) (3.8.1)
# Collecting python-docx (from Pattern)
#   Downloading python_docx-1.1.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting cherrypy (from Pattern)
#   Downloading CherryPy-18.9.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: requests in c:\users\anjan\anaconda3\lib\site-packages (from Pattern) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\anjan\anaconda3\lib\site-packages (from beautifulsoup4->Pattern) (2.5)
# Collecting cheroot>=8.2.1 (from cherrypy->Pattern)
#   Downloading cheroot-10.0.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting portend>=2.1.1 (from cherrypy->Pattern)
#   Downloading portend-3.2.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: more-itertools in c:\users\anjan\anaconda3\lib\site-packages (from cherrypy->Pattern) (10.1.0)
# Collecting zc.lockfile (from cherrypy->Pattern)
#   Downloading zc.lockfile-3.0.post1-py3-none-any.whl.metadata (6.2 kB)
# Collecting jaraco.collections (from cherrypy->Pattern)
#   Downloading jaraco.collections-5.0.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting sgmllib3k (from feedparser->Pattern)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: click in c:\users\anjan\anaconda3\lib\site-packages (from nltk->Pattern) (8.1.7)
# Requirement already satisfied: joblib in c:\users\anjan\anaconda3\lib\site-packages (from nltk->Pattern) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\anjan\anaconda3\lib\site-packages (from nltk->Pattern) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\anjan\anaconda3\lib\site-packages (from nltk->Pattern) (4.65.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\anjan\anaconda3\lib\site-packages (from pdfminer.six->Pattern) (2.0.4)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\anjan\anaconda3\lib\site-packages (from pdfminer.six->Pattern) (42.0.2)
# Requirement already satisfied: typing-extensions in c:\users\anjan\anaconda3\lib\site-packages (from python-docx->Pattern) (4.9.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anjan\anaconda3\lib\site-packages (from requests->Pattern) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anjan\anaconda3\lib\site-packages (from requests->Pattern) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anjan\anaconda3\lib\site-packages (from requests->Pattern) (2024.2.2)
# Collecting jaraco.functools (from cheroot>=8.2.1->cherrypy->Pattern)
#   Downloading jaraco.functools-4.0.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\anjan\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->Pattern) (1.16.0)
# Collecting tempora>=1.8 (from portend>=2.1.1->cherrypy->Pattern)
#   Downloading tempora-5.5.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: colorama in c:\users\anjan\anaconda3\lib\site-packages (from click->nltk->Pattern) (0.4.6)
# Collecting jaraco.text (from jaraco.collections->cherrypy->Pattern)
#   Downloading jaraco.text-3.12.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: setuptools in c:\users\anjan\anaconda3\lib\site-packages (from zc.lockfile->cherrypy->Pattern) (68.2.2)
# Requirement already satisfied: pycparser in c:\users\anjan\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->Pattern) (2.21)
# Requirement already satisfied: pytz in c:\users\anjan\anaconda3\lib\site-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->Pattern) (2023.3.post1)
# Collecting jaraco.context>=4.1 (from jaraco.text->jaraco.collections->cherrypy->Pattern)
#   Downloading jaraco.context-5.3.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting autocommand (from jaraco.text->jaraco.collections->cherrypy->Pattern)
#   Downloading autocommand-2.2.2-py3-none-any.whl.metadata (15 kB)
# Collecting inflect (from jaraco.text->jaraco.collections->cherrypy->Pattern)
#   Downloading inflect-7.2.0-py3-none-any.whl.metadata (21 kB)
# Collecting backports.tarfile (from jaraco.context>=4.1->jaraco.text->jaraco.collections->cherrypy->Pattern)
#   Downloading backports.tarfile-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting typeguard>=4.0.1 (from inflect->jaraco.text->jaraco.collections->cherrypy->Pattern)
#   Downloading typeguard-4.2.1-py3-none-any.whl.metadata (3.7 kB)
# Collec
 14.1 MB/s eta 0:00:01
#    ---------------------------------------- 239.6/239.6 kB 7.4 MB/s eta 0:00:00
# Downloading cheroot-10.0.0-py3-none-any.whl (101 kB)
#    ---------------------------------------- 0.0/101.6 kB ? eta -:--:--
#    ------------------------------------ --- 92.2/101.6 kB ? eta -:--:--
#    ---------------------------------------- 101.6/101.6 kB 1.2 MB/s eta 0:00:00
# Downloading portend-3.2.0-py3-none-any.whl (5.3 kB)
# Downloading jaraco.collections-5.0.1-py3-none-any.whl (10 kB)
# Downloading zc.lockfile-3.0.post1-py3-none-any.whl (9.8 kB)
# Downloading tempora-5.5.1-py3-none-any.whl (13 kB)
# Downloading jaraco.functools-4.0.0-py3-none-any.whl (9.8 kB)
# Downloading jaraco.text-3.12.0-py3-none-any.whl (11 kB)
# Downloading jaraco.context-5.3.0-py3-none-any.whl (6.5 kB)
# Downloading autocommand-2.2.2-py3-none-any.whl (19 kB)
# Downloading inflect-7.2.0-py3-none-any.whl (34 kB)
# Downloading typeguard-4.2.1-py3-none-any.whl (34 kB)
# Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Downloading backports.tarfile-1.1.0-py3-none-any.whl (29 kB)
# Building wheels for collected packages: Pattern, sgmllib3k
#   Building wheel for Pattern (setup.py): started
#   Building wheel for Pattern (setup.py): finished with status 'done'
#   Created wheel for Pattern: filename=Pattern-3.6-py3-none-any.whl size=22332713 sha256=311b4eac64a650178a7f8ce3640d9fa0208cf1ebc0d5ce93cdc6f142407ece4c
#   Stored in directory: c:\users\anjan\appdata\local\pip\cache\wheels\d0\8d\e1\44b5ab952791ca07e66a780d11dbf141c49d151f0be21e811b
#   Building wheel for sgmllib3k (setup.py): started
#   Building wheel for sgmllib3k (setup.py): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6061 sha256=5849ebe4fbe7d2f5b4b13ec1c941a8cf69a4f8bf9eebac742d7e4daf04c01e12
#   Stored in directory: c:\users\anjan\appdata\local\pip\cache\wheels\3b\25\2a\105d6a15df6914f4d15047691c6c28f9052cc1173e40285d03
# Successfully built Pattern sgmllib3k
# Installing collected packages: sgmllib3k, backports.csv, zc.lockfile, typing-extensions, mysqlclient, jaraco.functools, feedparser, backports.tarfile, autocommand, typeguard, tempora, python-docx, jaraco.context, cheroot, portend, pdfminer.six, inflect, jaraco.text, jaraco.collections, cherrypy, Pattern
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
# Successfully installed Pattern-3.6 autocommand-2.2.2 backports.csv-1.0.7 backports.tarfile-1.1.0 cheroot-10.0.0 cherrypy-18.9.0 feedparser-6.0.11 inflect-7.2.0 jaraco.collections-5.0.1 jaraco.context-5.3.0 jaraco.functools-4.0.0 jaraco.text-3.12.0 mysqlclient-2.2.4 pdfminer.six-20231228 portend-3.2.0 python-docx-1.1.0 sgmllib3k-1.0.0 tempora-5.5.1 typeguard-4.2.1 typing-extensions-4.11.0 zc.lockfile-3.0.post1

# %%
# !pip install confplot
# Out:
# Collecting confplot
#   Downloading confplot-0.1.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\anjan\anaconda3\lib\site-packages (from confplot) (1.26.4)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\anjan\anaconda3\lib\site-packages (from confplot) (3.8.0)
# Requirement already satisfied: scikit-learn>=0.22.2 in c:\users\anjan\anaconda3\lib\site-packages (from confplot) (1.2.2)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\anjan\anaconda3\lib\site-packages (from confplot) (2.1.4)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\anjan\anaconda3\lib\site-packages (from confplot) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anjan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->confplot) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\anjan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->confplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anjan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->confplot) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anjan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->confplot) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\anjan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->confplot) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anjan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->confplot) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anjan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->confplot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anjan\anaconda3\lib\site-packages (from matplotlib>=3.0.0->confplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anjan\anaconda3\lib\site-packages (from pandas>=1.0.0->confplot) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\anjan\anaconda3\lib\site-packages (from pandas>=1.0.0->confplot) (2023.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\anjan\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->confplot) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\anjan\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->confplot) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anjan\anaconda3\lib\site-packages (from scikit-learn>=0.22.2->confplot) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\anjan\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->confplot) (1.16.0)
# Downloading confplot-0.1.1-py3-none-any.whl (10 kB)
# Installing collected packages: confplot
# Successfully installed confplot-0.1.1

# %%
noundict = {'i':'me', 'we':'us', 'you':'you', 'he':'him', 'she':'her', 'they':'them', 'them':'they', 'her':'she', 'him':'he', 'us':'we', 'me':'i'}

def nouninv(noun):
    n = noun.lower()
    if n in noundict:
        return noundict[n]
    return noun

# %%
import spacy
import pattern.en as en


nlp = spacy.load("en_core_web_sm")

def act2pass(doc, rec=False):
    parse = nlp(doc)
    newdoc = ''
    for sent in parse.sents:
        # Init parts of sentence to capture:
        subj = ''
        verb = ''
        verbtense = ''
        verbaspect = ''
        adverb = {'bef':'', 'aft':''}
        part = ''
        prep = ''
        obj = ''
        objplural = False
        advcltree = None
        aux = list(list(nlp('. .').sents)[0]) # start with 2 'null' elements
        xcomp = ''
        punc = '.'

        # Analyse dependency tree:
        for word in sent:
            if word.dep_ == 'advcl':
                if word.head.dep_ in ('ROOT', 'verb'):
                    advcltree = word.subtree
            if word.dep_ == 'nsubj':
                subj = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_ in ('advmod','npadvmod','oprd'):
                if word.head.dep_ == 'ROOT':
                    if verb == '':
                        adverb['bef'] = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
                    else:
                        adverb['aft'] = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_ == 'ROOT':
                verb = word.text
                if word.tag_ == 'VB':
                    verbtense = en.INFINITIVE
                elif word.tag_ == 'VBD':
                    verbtense = en.PAST
                elif word.tag_ == 'VBG':
                    verbtense = en.PRESENT
                    verbaspect = en.PROGRESSIVE
                elif word.tag_ == 'VBN':
                    verbtense = en.PAST
                else:
                    verbtense = en.tenses(word.text)[0][0]
            if word.dep_ == 'prt':
                if word.head.dep_ == 'ROOT':
                    part = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_ == 'prep':
                if word.head.dep_ == 'ROOT':
                    prep = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_.endswith('obj'):
                if word.head.dep_ == 'ROOT':
                    obj = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
                    objplural = word.tag_ in ('NNS','NNPS')
            if word.dep_ in ('xcomp','ccomp','conj'):
                if word.head.dep_ == 'ROOT':
                    xcomp = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
                    that = xcomp.startswith('that')
                    xcomp = act2pass(xcomp, True).strip(' .')
                    if not xcomp.startswith('that') and that:
                        xcomp = 'that '+xcomp
            if word.dep_ == 'punct' and not rec:
                if word.text != '"':
                    punc = word.text

        # invert nouns:
        subj = nouninv(subj)
        obj = nouninv(obj)

        # FUCKING CONJUGATION!!!!!!!!!!!!!:
        auxstr = ''
        num = en.SINGULAR if not objplural or obj in ('he','she') else en.PLURAL
        aux.append(aux[0])
        verbaspect = None
        for (pp, p, a, n) in zip(aux,aux[1:],aux[2:],aux[3:]):
            if a.lemma_ == '.':
                continue

            if a.lemma_ == 'not':
                if p.lemma_ == 'be':
                    if n.lemma_ == 'be':
                        verbtense = en.tenses(a.text)[0][0]
                        auxstr += en.conjugate('be',tense=en.tenses(p.text)[0][0],number=num) + ' '
                        verbaspect = en.PROGRESSIVE
                    else:
                        auxstr += en.conjugate('do',tense=en.tenses(p.text)[0][0],number=num) + ' '
                        verbtense = en.INFINITIVE
                auxstr += 'not '
            elif a.lemma_ == 'be':
                if p.lemma_ == 'be':
                    verbtense = en.tenses(a.text)[0][0]
                    auxstr += en.conjugate('be',tense=en.tenses(a.text)[0][0],number=num) + ' '
                    verbaspect = en.PROGRESSIVE
                elif p.tag_ == 'MD':
                    verbtense = en.INFINITIVE
            elif a.lemma_ == 'have':
                num == en.PLURAL if p.tag_ == 'MD' else num
                auxstr += en.conjugate('have',tense=en.tenses(a.text)[0][0],number=num) + ' '
                if n.lemma_ == 'be':
                    verbaspect = en.PROGRESSIVE
                    verbtense = en.tenses(n.text)[0][0]
            else:
                auxstr += a.text_with_ws
        auxstr = auxstr.lower().strip()

        if verbaspect:
            verb = en.conjugate(verb,tense=verbtense,aspect=verbaspect)
        else:
            verb = en.conjugate(verb,tense=verbtense)

        advcl = ''
        if advcltree:
            for w in advcltree:
                if w.pos_ == 'VERB' and en.tenses(w.text)[0][4] == en.PROGRESSIVE:
                    advcl += 'which ' + en.conjugate(w.text,tense=en.tenses(verb)[0][0]) + ' '
                else:
                    advcl += w.text_with_ws

        newsent = ' '.join(list(filter(None, [obj, 'was' if num == en.SINGULAR else 'were', adverb['bef'], verb, part, 'by', subj, adverb['aft'], advcl, prep, xcomp]))) + punc
        if not rec:
            newsent = newsent[0].upper() + newsent[1:]
        newdoc += newsent + ' '
    return newdoc

def pass2act(doc, rec=False):
    parse = nlp(doc)
    newdoc = ''
    for sent in parse.sents:
        # Init parts of sentence to capture:
        subjpass = ''
        subj = ''
        verb = ''
        verbtense = ''
        verbaspect = ''
        adverb = {'bef':'', 'aft':''}
        part = ''
        prep = ''
        agent = ''
        aplural = False
        advcltree = None
        aux = list(list(nlp('. .').sents)[0]) # start with 2 'null' elements
        xcomp = ''
        punc = '.'

        # Analyse dependency tree:
        for word in sent:
            if word.dep_ == 'advcl':
                if word.head.dep_ in ('ROOT', 'auxpass'):
                    advcltree = word.subtree
            if word.dep_ == 'nsubjpass':
                if word.head.dep_ == 'ROOT':
                    subjpass = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_ == 'nsubj':
                subj = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
                if word.head.dep_ == 'auxpass':
                    if word.head.head.dep_ == 'ROOT':
                        subjpass = subj
            if word.dep_ in ('advmod','npadvmod','oprd'):
                if word.head.dep_ == 'ROOT':
                    if verb == '':
                        adverb['bef'] = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
                    else:
                        adverb['aft'] = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_ == 'auxpass':
                if word.head.dep_ == 'ROOT':
                    if not subjpass:
                        subjpass = subj
            if word.dep_ in ('aux','auxpass','neg'):
                if word.head.dep_ == 'ROOT':
                    aux += [word]
            if word.dep_ == 'ROOT':
                verb = word.text
                if word.tag_ == 'VB':
                    verbtense = en.INFINITIVE
                elif word.tag_ == 'VBD':
                    verbtense = en.PAST
                elif word.tag_ == 'VBG':
                    verbtense = en.PRESENT
                    verbaspect = en.PROGRESSIVE
                elif word.tag_ == 'VBN':
                    verbtense = en.PAST
                else:
                    verbtense = en.tenses(word.text)[0][0]
            if word.dep_ == 'prt':
                if word.head.dep_ == 'ROOT':
                    part = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_ == 'prep':
                if word.head.dep_ == 'ROOT':
                    prep = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_.endswith('obj'):
                if word.head.dep_ == 'agent':
                    if word.head.head.dep_ == 'ROOT':
                        agent = ''.join(w.text + ', ' if w.dep_=='appos' else (w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws) for w in word.subtree).strip()
                        aplural = word.tag_ in ('NNS','NNPS')
            if word.dep_ in ('xcomp','ccomp','conj'):
                if word.head.dep_ == 'ROOT':
                    xcomp = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
                    that = xcomp.startswith('that')
                    xcomp = pass2act(xcomp, True).strip(' .')
                    if not xcomp.startswith('that') and that:
                        xcomp = 'that '+xcomp
            if word.dep_ == 'punct' and not rec:
                if word.text != '"':
                    punc = word.text

        # exit if not passive:
        if subjpass == '':
            newdoc += str(sent) + ' '
            continue

        # if no agent is found:
        if agent == '':
            # what am I gonna do? BITconEEEEEEECT!!!!
            newdoc += str(sent) + ' '
            continue

        # invert nouns:
        agent = nouninv(agent)
        subjpass = nouninv(subjpass)

        # FUCKING CONJUGATION!!!!!!!!!!!!!:
        auxstr = ''
        num = en.SINGULAR if not aplural or agent in ('he','she') else en.PLURAL
        aux.append(aux[0])
        verbaspect = None
        for (pp, p, a, n) in zip(aux,aux[1:],aux[2:],aux[3:]):
            if a.lemma_ == '.':
                continue

            if a.lemma_ == 'not':
                if p.lemma_ == 'be':
                    if n.lemma_ == 'be':
                        verbtense = en.tenses(a.text)[0][0]
                        auxstr += en.conjugate('be',tense=en.tenses(p.text)[0][0],number=num) + ' '
                        verbaspect = en.PROGRESSIVE
                    else:
                        auxstr += en.conjugate('do',tense=en.tenses(p.text)[0][0],number=num) + ' '
                        verbtense = en.INFINITIVE
                auxstr += 'not '
            elif a.lemma_ == 'be':
                if p.lemma_ == 'be':
                    verbtense = en.tenses(a.text)[0][0]
                    auxstr += en.conjugate('be',tense=en.tenses(a.text)[0][0],number=num) + ' '
                    verbaspect = en.PROGRESSIVE
                elif p.tag_ == 'MD':
                    verbtense = en.INFINITIVE
            elif a.lemma_ == 'have':
                num == en.PLURAL if p.tag_ == 'MD' else num
                auxstr += en.conjugate('have',tense=en.tenses(a.text)[0][0],number=num) + ' '
                if n.lemma_ == 'be':
                    verbaspect = en.PROGRESSIVE
                    verbtense = en.tenses(n.text)[0][0]
            else:
                auxstr += a.text_with_ws
        auxstr = auxstr.lower().strip()

        if verbaspect:
            verb = en.conjugate(verb,tense=verbtense,aspect=verbaspect)
        else:
            verb = en.conjugate(verb,tense=verbtense)

        advcl = ''
        if advcltree:
            for w in advcltree:
                if w.pos_ == 'VERB' and en.tenses(w.text)[0][4] == en.PROGRESSIVE:
                    advcl += 'which ' + en.conjugate(w.text,tense=en.tenses(verb)[0][0]) + ' '
                else:
                    advcl += w.text_with_ws

        newsent = ' '.join

# %%
# Active to Passive
active_sentence = "The dog chased the cat."
passive_sentence = act2pass(active_sentence)
print(passive_sentence)
# Output: The cat was chased by the dog.
# Out:
# The cat was chased by the dog.

# %%
def act2pass(doc, rec=False):
    parse = nlp(doc)
    newdoc = ''
    for sent in parse.sents:
        # Init parts of sentence to capture:
        subj = ''
        verb = ''
        verbtense = ''
        verbaspect = ''
        adverb = {'bef':'', 'aft':''}
        part = ''
        prep = ''
        obj = ''
        objplural = False
        advcltree = None
        aux = list(list(nlp('. .').sents)[0]) # start with 2 'null' elements
        xcomp = ''
        punc = '.'

        # Analyse dependency tree:
        for word in sent:
            if word.dep_ == 'advcl':
                if word.head.dep_ in ('ROOT', 'verb'):
                    advcltree = word.subtree
            if word.dep_ == 'nsubj':
                subj = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_ in ('advmod','npadvmod','oprd'):
                if word.head.dep_ == 'ROOT':
                    if verb == '':
                        adverb['bef'] = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
                    else:
                        adverb['aft'] = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_ == 'ROOT':
                verb = word.text
                if word.tag_ == 'VB':
                    verbtense = en.INFINITIVE
                elif word.tag_ == 'VBD':
                    verbtense = en.PAST
                elif word.tag_ == 'VBG':
                    verbtense = en.PRESENT
                    verbaspect = en.PROGRESSIVE
                elif word.tag_ == 'VBN':
                    verbtense = en.PAST
                else:
                    verbtense = en.tenses(word.text)[0][0]
            if word.dep_ == 'prt':
                if word.head.dep_ == 'ROOT':
                    part = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_ == 'prep':
                if word.head.dep_ == 'ROOT':
                    prep = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_.endswith('obj'):
                if word.head.dep_ == 'ROOT':
                    obj = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
                    objplural = word.tag_ in ('NNS','NNPS')
            if word.dep_ in ('xcomp','ccomp','conj'):
                if word.head.dep_ == 'ROOT':
                    xcomp = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
                    that = xcomp.startswith('that')
                    xcomp = act2pass(xcomp, True).strip(' .')
                    if not xcomp.startswith('that') and that:
                        xcomp = 'that '+xcomp
            if word.dep_ == 'punct' and not rec:
                if word.text != '"':
                    punc = word.text

        # invert nouns:
        subj = nouninv(subj)
        obj = nouninv(obj)

        # FUCKING CONJUGATION!!!!!!!!!!!!!:
        auxstr = ''
        num = en.SINGULAR if not objplural or obj in ('he','she') else en.PLURAL
        aux.append(aux[0])
        verbaspect = None
        for (pp, p, a, n) in zip(aux,aux[1:],aux[2:],aux[3:]):
            if a.lemma_ == '.':
                continue

            if a.lemma_ == 'not':
                if p.lemma_ == 'be':
                    if n.lemma_ == 'be':
                        verbtense = en.tenses(a.text)[0][0]
                        auxstr += en.conjugate('be',tense=en.tenses(p.text)[0][0],number=num) + ' '
                        verbaspect = en.PROGRESSIVE
                    else:
                        auxstr += en.conjugate('do',tense=en.tenses(p.text)[0][0],number=num) + ' '
                        verbtense = en.INFINITIVE
                auxstr += 'not '
            elif a.lemma_ == 'be':
                if p.lemma_ == 'be':
                    verbtense = en.tenses(a.text)[0][0]
                    auxstr += en.conjugate('be',tense=en.tenses(a.text)[0][0],number=num) + ' '
                    verbaspect = en.PROGRESSIVE
                elif p.tag_ == 'MD':
                    verbtense = en.INFINITIVE
            elif a.lemma_ == 'have':
                num == en.PLURAL if p.tag_ == 'MD' else num
                auxstr += en.conjugate('have',tense=en.tenses(a.text)[0][0],number=num) + ' '
                if n.lemma_ == 'be':
                    verbaspect = en.PROGRESSIVE
                    verbtense = en.tenses(n.text)[0][0]
            else:
                auxstr += a.text_with_ws
        auxstr = auxstr.lower().strip()

        if verbaspect:
            verb = en.conjugate(verb,tense=verbtense,aspect=verbaspect)
        else:
            verb = en.conjugate(verb,tense=verbtense)

        advcl = ''
        if advcltree:
            for w in advcltree:
                if w.pos_ == 'VERB' and en.tenses(w.text)[0][4] == en.PROGRESSIVE:
                    advcl += 'which ' + en.conjugate(w.text,tense=en.tenses(verb)[0][0]) + ' '
                else:
                    advcl += w.text_with_ws

        newsent = ' '.join(list(filter(None, [obj, 'was' if num == en.SINGULAR else 'were', adverb['bef'], verb, part, 'by', subj, adverb['aft'], advcl, prep, xcomp]))) + punc
        if not rec:
            newsent = newsent[0].upper() + newsent[1:]
        newdoc += newsent + ' '
    return newdoc

def pass2act(doc, rec=False):
    parse = nlp(doc)
    newdoc = ''
    for sent in parse.sents:
        # Init parts of sentence to capture:
        subjpass = ''
        subj = ''
        verb = ''
        verbtense = ''
        verbaspect = ''
        adverb = {'bef':'', 'aft':''}
        part = ''
        prep = ''
        agent = ''
        aplural = False
        advcltree = None
        aux = list(list(nlp('. .').sents)[0]) # start with 2 'null' elements
        xcomp = ''
        punc = '.'

        # Analyse dependency tree:
        for word in sent:
            if word.dep_ == 'advcl':
                if word.head.dep_ in ('ROOT', 'auxpass'):
                    advcltree = word.subtree
            if word.dep_ == 'nsubjpass':
                if word.head.dep_ == 'ROOT':
                    subjpass = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_ == 'nsubj':
                subj = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
                if word.head.dep_ == 'auxpass':
                    if word.head.head.dep_ == 'ROOT':
                        subjpass = subj
            if word.dep_ in ('advmod','npadvmod','oprd'):
                if word.head.dep_ == 'ROOT':
                    if verb == '':
                        adverb['bef'] = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
                    else:
                        adverb['aft'] = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_ == 'auxpass':
                if word.head.dep_ == 'ROOT':
                    if not subjpass:
                        subjpass = subj
            if word.dep_ in ('aux','auxpass','neg'):
                if word.head.dep_ == 'ROOT':
                    aux += [word]
            if word.dep_ == 'ROOT':
                verb = word.text
                if word.tag_ == 'VB':
                    verbtense = en.INFINITIVE
                elif word.tag_ == 'VBD':
                    verbtense = en.PAST
                elif word.tag_ == 'VBG':
                    verbtense = en.PRESENT
                    verbaspect = en.PROGRESSIVE
                elif word.tag_ == 'VBN':
                    verbtense = en.PAST
                else:
                    verbtense = en.tenses(word.text)[0][0]
            if word.dep_ == 'prt':
                if word.head.dep_ == 'ROOT':
                    part = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_ == 'prep':
                if word.head.dep_ == 'ROOT':
                    prep = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
            if word.dep_.endswith('obj'):
                if word.head.dep_ == 'agent':
                    if word.head.head.dep_ == 'ROOT':
                        agent = ''.join(w.text + ', ' if w.dep_=='appos' else (w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws) for w in word.subtree).strip()
                        aplural = word.tag_ in ('NNS','NNPS')
            if word.dep_ in ('xcomp','ccomp','conj'):
                if word.head.dep_ == 'ROOT':
                    xcomp = ''.join(w.text_with_ws.lower() if w.tag_ not in ('NNP','NNPS') else w.text_with_ws for w in word.subtree).strip()
                    that = xcomp.startswith('that')
                    xcomp = pass2act(xcomp, True).strip(' .')
                    if not xcomp.startswith('that') and that:
                        xcomp = 'that '+xcomp
            if word.dep_ == 'punct' and not rec:
                if word.text != '"':
                    punc = word.text

        # exit if not passive:
        if subjpass == '':
            newdoc += str(sent) + ' '
            continue

        # if no agent is found:
        if agent == '':
            # what am I gonna do? BITconEEEEEEECT!!!!
            newdoc += str(sent) + ' '
            continue

        # invert nouns:
        agent = nouninv(agent)
        subjpass = nouninv(subjpass)

        # FUCKING CONJUGATION!!!!!!!!!!!!!:
        auxstr = ''
        num = en.SINGULAR if not aplural or agent in ('he','she') else en.PLURAL
        aux.append(aux[0])
        verbaspect = None
        for (pp, p, a, n) in zip(aux,aux[1:],aux[2:],aux[3:]):
            if a.lemma_ == '.':
                continue

            if a.lemma_ == 'not':
                if p.lemma_ == 'be':
                    if n.lemma_ == 'be':
                        verbtense = en.tenses(a.text)[0][0]
                        auxstr += en.conjugate('be',tense=en.tenses(p.text)[0][0],number=num) + ' '
                        verbaspect = en.PROGRESSIVE
                    else:
                        auxstr += en.conjugate('do',tense=en.tenses(p.text)[0][0],number=num) + ' '
                        verbtense = en.INFINITIVE
                auxstr += 'not '
            elif a.lemma_ == 'be':
                if p.lemma_ == 'be':
                    verbtense = en.tenses(a.text)[0][0]
                    auxstr += en.conjugate('be',tense=en.tenses(a.text)[0][0],number=num) + ' '
                    verbaspect = en.PROGRESSIVE
                elif p.tag_ == 'MD':
                    verbtense = en.INFINITIVE
            elif a.lemma_ == 'have':
                num == en.PLURAL if p.tag_ == 'MD' else num
                auxstr += en.conjugate('have',tense=en.tenses(a.text)[0][0],number=num) + ' '
                if n.lemma_ == 'be':
                    verbaspect = en.PROGRESSIVE
                    verbtense = en.tenses(n.text)[0][0]
            else:
                auxstr += a.text_with_ws
        auxstr = auxstr.lower().strip()

        if verbaspect:
            verb = en.conjugate(verb,tense=verbtense,aspect=verbaspect)
        else:
            verb = en.conjugate(verb,tense=verbtense)

        advcl = ''
        if advcltree:
            for w in advcltree:
                if w.pos_ == 'VERB' and en.tenses(w.text)[0][4] == en.PROGRESSIVE:
                    advcl += 'which ' + en.conjugate(w.text,tense=en.tenses(verb)[0][0]) + ' '
                else:
                    advcl += w.text_with_ws

        newsent = ' '

# %%
# Passive to Active
passive_sentence = "The cat was chased by the dog."
active_sentence = pass2act(passive_sentence)
print(active_sentence)
# Output: The dog chased the cat.
# Out:
# None

# %%
# Example usage
active_sentences = [
    "The dog chased the cat.",
    "The student writes the essay.",
    "John has repaired the car.",
    "The scientist discovered a new planet."
]

passive_sentences = [
    "The cat was chased by the dog.",
    "The essay is written by the student.",
    "The car has been repaired by John.",
    "A new planet was discovered by the scientist."
]

# Convert active to passive
for active_sentence in active_sentences:
    passive_sentence = act2pass(active_sentence)
    print(f"Active: {active_sentence}")
    print(f"Passive: {passive_sentence}")
    print()

# Convert passive to active
for passive_sentence in passive_sentences:
    active_sentence = pass2act(passive_sentence)
    print(f"Passive: {passive_sentence}")
    print(f"Active: {active_sentence}")
    print()
# Out:
# Active: The dog chased the cat.
# Passive: The cat was chased by the dog.
#
# Active: The student writes the essay.
# Passive: The essay was writes by the student.
#
# Active: John has repaired the car.
# Passive: The car was repaired by John.
#
# Active: The scientist discovered a new planet.
# Passive: A new planet was discovered by the scientist.
#
# Passive: The cat was chased by the dog.
# Active: None
#
# Passive: The essay is written by the student.
# Active: None
#
# Passive: The car has been repaired by John.
# Active: None
#
# Passive: A new planet was discovered by the scientist.
# Active: None
